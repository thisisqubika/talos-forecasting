# %%
import pycaret
from pycaret.time_series import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError, MeanAbsoluteScaledError, MedianAbsoluteScaledError

# %%
df_in = pd.read_csv("data/monthly_in.csv")
df_out = pd.read_csv("data/monthly_oos.csv")[3:]

# %%
forecast_horizon = [1,2,3,6,12,18,24]

# %%
mape = MeanAbsolutePercentageError()
mase = MeanAbsoluteScaledError()
mdase = MedianAbsoluteScaledError()

# %%
experiments = []
for col in df_in.columns:
    df_train = df_in.loc[:df_in[col].notna()[::-1].idxmax(),col]
    df_test = df_out.loc[:df_out[col].notna()[::-1].idxmax(),col]
    for fh in forecast_horizon:
        print(f"training model: {col}, fh: {fh}")
        exp = {}
        s = setup(df_train,fh=fh, session_id=42,verbose=False)
        best = compare_models(verbose=False, sort="MAPE")
        best_final = finalize_model(best)
        
        df_pred = predict_model(best_final, fh=fh)
        df_test_fh = df_test[:fh]
        exp["serie"] = col
        exp["fh"] = fh
        exp["best_model"] = best_final
        exp["model_path"] = f"models/{col}_{fh}"
        exp["MAPE"] = mape(y_true=df_test_fh,y_pred=df_pred)
        exp["MASE"] = mase(y_true=df_test_fh,y_pred=df_pred,y_train=df_train)
        exp["MdASE"] = mdase(y_true=df_test_fh,y_pred=df_pred,y_train=df_train)
        save_model(best_final, f"models/{col}_{fh}")
        experiments.append(exp)
        if(len(experiments)%50==0):
            pd.DataFrame(experiments).to_csv("results/model_results.csv",index=False)

pd.DataFrame(experiments).to_csv("results/model_results.csv",index=False)
# Out:
# training model: m1, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m1, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m1, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m1, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m1, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m1, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m1, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m2, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m3, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m4, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m5, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m6, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m7, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m8, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m9, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m10, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m11, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m12, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m13, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m14, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m15, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m16, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m17, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m18, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m19, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m20, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m21, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m22, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m23, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m24, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m25, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m26, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m27, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m28, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m29, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m30, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m31, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m32, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m33, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m34, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m35, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m36, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m37, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m38, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m39, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m40, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m41, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m42, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m43, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m44, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m45, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m46, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m47, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m48, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m49, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m50, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m51, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m52, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m53, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m54, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m55, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m56, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m57, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m58, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m59, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m60, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m61, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m62, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m63, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m64, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m65, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m66, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m67, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m68, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m69, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m70, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m71, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m72, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m73, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m74, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m75, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m76, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m77, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m78, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m79, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m80, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m81, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m82, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m83, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m84, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m85, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m86, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m86, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m86, fh: 3
# ...
# training model: m132, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m132, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m132, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m132, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m133, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m134, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m135, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m136, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m137, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m138, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m139, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m140, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m141, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m142, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m143, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m144, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 18
# Transformation Pipeline and Model Successfully Saved
# training model: m145, fh: 24
# Transformation Pipeline and Model Successfully Saved
# training model: m146, fh: 1
# Transformation Pipeline and Model Successfully Saved
# training model: m146, fh: 2
# Transformation Pipeline and Model Successfully Saved
# training model: m146, fh: 3
# Transformation Pipeline and Model Successfully Saved
# training model: m146, fh: 6
# Transformation Pipeline and Model Successfully Saved
# training model: m146, fh: 12
# Transformation Pipeline and Model Successfully Saved
# training model: m146, fh: 18
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/marcoluquer/projects/talos-forecasting/forecasting_monthly_modeling.ipynb Cell 5 line 8
#       <a href='vscode-notebook-cell:/Users/marcoluquer/projects/talos-forecasting/forecasting_monthly_modeling.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a> print(f"training model: {col}, fh: {fh}")
#       <a href='vscode-notebook-cell:/Users/marcoluquer/projects/talos-forecasting/forecasting_monthly_modeling.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a> exp = {}
# ----> <a href='vscode-notebook-cell:/Users/marcoluquer/projects/talos-forecasting/forecasting_monthly_modeling.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> s = setup(df_train,fh=fh, session_id=42,verbose=False)
#       <a href='vscode-notebook-cell:/Users/marcoluquer/projects/talos-forecasting/forecasting_monthly_modeling.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a> best = compare_models(verbose=False, sort="MAPE")
#      <a href='vscode-notebook-cell:/Users/marcoluquer/projects/talos-forecasting/forecasting_monthly_modeling.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> best_final = finalize_model(best)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/pycaret/time_series/forecasting/functional.py:590, in setup(data, data_func, target, index, ignore_features, numeric_imputation_target, numeric_imputation_exogenous, transform_target, transform_exogenous, fe_target_rr, fe_exogenous, scale_target, scale_exogenous, fold_strategy, fold, fh, hyperparameter_split, seasonal_period, ignore_seasonality_test, sp_detection, max_sp_to_consider, remove_harmonics, harmonic_order_method, num_sps_to_use, seasonality_type, point_alpha, coverage, enforce_exogenous, n_jobs, use_gpu, custom_pipeline, html, session_id, system_log, log_experiment, experiment_name, log_plots, log_profile, log_data, verbose, profile, profile_kwargs, fig_kwargs)
#     588 exp = _EXPERIMENT_CLASS()
#     589 set_current_experiment(exp)
# --> 590 return exp.setup(
#     591     data=data,
#     592     data_func=data_func,
#     593     target=target,
#     594     index=index,
#     595     ignore_features=ignore_features,
#     596     numeric_imputation_target=numeric_imputation_target,
#     597     numeric_imputation_exogenous=numeric_imputation_exogenous,
#     598     transform_target=transform_target,
#     599     transform_exogenous=transform_exogenous,
#     600     scale_target=scale_target,
#     601     scale_exogenous=scale_exogenous,
#     602     fe_target_rr=fe_target_rr,
#     603     fe_exogenous=fe_exogenous,
#     604     fold_strategy=fold_strategy,
#     605     fold=fold,
#     606     fh=fh,
#     607     hyperparameter_split=hyperparameter_split,
#     608     seasonal_period=seasonal_period,
#     609     ignore_seasonality_test=ignore_seasonality_test,
#     610     sp_detection=sp_detection,
#     611     max_sp_to_consider=max_sp_to_consider,
#     612     remove_harmonics=remove_harmonics,
#     613     harmonic_order_method=harmonic_order_method,
#     614     num_sps_to_use=num_sps_to_use,
#     615     seasonality_type=seasonality_type,
#     616     point_alpha=point_alpha,
#     617     coverage=coverage,
#     618     enforce_exogenous=enforce_exogenous,
#     619     n_jobs=n_jobs,
#     620     use_gpu=use_gpu,
#     621     custom_pipeline=custom_pipeline,
#     622     html=html,
#     623     session_id=session_id,
#     624     system_log=system_log,
#     625     log_experiment=log_experiment,
#     626     experiment_name=experiment_name,
#     627     log_plots=log_plots,
#     628     log_profile=log_profile,
#     629     log_data=log_data,
#     630     verbose=verbose,
#     631     profile=profile,
#     632     profile_kwargs=profile_kwargs,
#     633     fig_kwargs=fig_kwargs,
#     634 )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/pycaret/time_series/forecasting/oop.py:2116, in TSForecastingExperiment.setup(self, data, data_func, target, index, ignore_features, numeric_imputation_target, numeric_imputation_exogenous, transform_target, transform_exogenous, scale_target, scale_exogenous, fe_target_rr, fe_exogenous, fold_strategy, fold, fh, hyperparameter_split, seasonal_period, ignore_seasonality_test, sp_detection, max_sp_to_consider, remove_harmonics, harmonic_order_method, num_sps_to_use, seasonality_type, point_alpha, coverage, enforce_exogenous, n_jobs, use_gpu, custom_pipeline, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, profile, profile_kwargs, fig_kwargs)
#    2091 # Features to be ignored (are not read by self.dataset, self.X, etc...)
#    2092 self._fxs = {"Ignore": ignore_features or []}
#    2094 (
#    2095     self._initialize_setup(
#    2096         n_jobs=n_jobs,
#    2097         use_gpu=use_gpu,
#    2098         html=html,
#    2099         session_id=session_id,
#    2100         system_log=system_log,
#    2101         log_experiment=log_experiment,
#    2102         experiment_name=experiment_name,
#    2103         memory=True,
#    2104         verbose=verbose,
#    2105     )
#    2106     ._check_clean_and_set_data(data)
#    2107     ._check_and_clean_index(index=index, seasonal_period=seasonal_period)
#    2108     ._check_and_set_targets(target=target)
#    2109     ._set_exogenous_names()
#    2110     ._check_and_set_forecasting_types()
#    2111     ._check_and_set_fh(fh=fh)
#    2112     ._set_point_alpha_intervals_enforce_pi(
#    2113         point_alpha=point_alpha, coverage=coverage
#    2114     )
#    2115     ._setup_train_test_split()
# -> 2116     ._set_fold_generator()
#    2117     ._set_should_preprocess_data()
#    2118     ._set_missingness()
#    2119     ._initialize_pipeline()
#    2120     ##################################################################
#    2121     # Do these after the preprocessing pipeline has been setup.
#    2122     # Since the model will see transformed data, these parameters
#    2123     # should also be derived from the transformed data.
#    2124     ##################################################################
#    2125     ._check_and_set_seasonal_period()
#    2126     ._set_seasonal_type(seasonality_type=seasonality_type)
#    2127     ._perform_setup_eda()
#    2128     ._setup_display_container()
#    2129     ._profile(profile, profile_kwargs)
#    2130     ._set_exp_model_engines(
#    2131         container_default_engines=get_container_default_engines(),
#    2132         engine=engine,
#    2133     )
#    2134     ._set_all_models()
#    2135     ._set_all_metrics()
#    2136 )
#    2138 runtime = np.array(time.time() - runtime_start).round(2)
#    2140 self._set_up_logging(
#    2141     runtime,
#    2142     log_data,
#    2143     log_profile,
#    2144     experiment_custom_tags=experiment_custom_tags,
#    2145 )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/pycaret/time_series/forecasting/oop.py:987, in TSForecastingExperiment._set_fold_generator(self)
#     984 if self.fold_strategy in possible_time_series_fold_strategies:
#     985     # Number of folds
#     986     self.fold_param = self.fold
# --> 987     self.fold_generator = self.get_fold_generator(fold=self.fold_param)
#     988 else:
#     989     self.fold_generator = self.fold_strategy
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/pycaret/time_series/forecasting/oop.py:5172, in TSForecastingExperiment.get_fold_generator(self, fold, fold_strategy)
#    5169 initial_window = y_size - ((fold - 1) * step_length + 1 * fh_max_length)
#    5171 if initial_window < 1:
# -> 5172     raise ValueError(
#    5173         "Not Enough Data Points, set a lower number of folds or fh"
#    5174     )
#    5176 # If None, get the strategy defined in the setup (e.g. `expanding`, 'sliding`, etc.)
#    5177 if fold_strategy is None:
#
# ValueError: Not Enough Data Points, set a lower number of folds or fh

# %%
df = pd.read_csv("results/model_results_146.csv")

# %%
df.groupby("fh")[["MAPE","MASE","MdASE"]].mean()
# Out:
#         MAPE      MASE     MdASE
# fh
# 1   0.155821  1.077929  2.183776
# 2   0.133685  0.881015  1.617559
# 3   0.147418  0.882172  1.567817
# 6   0.195138  1.210358  2.098275
# 12  0.211483  1.279099  2.169362
# 18  0.199667  1.153020  1.968321
# 24  0.201196  1.277571  2.223683

# %%
#1-3
df.groupby("fh")[["MAPE","MASE","MdASE"]].mean()[:3].mean()
# Out:
# MAPE     0.145642
# MASE     0.947038
# MdASE    1.789717
# dtype: float64

# %%
#1-12
df.groupby("fh")[["MAPE","MASE","MdASE"]].mean()[:5].mean()
# Out:
# MAPE     0.168709
# MASE     1.066114
# MdASE    1.927358
# dtype: float64

# %%
#1-24
df.groupby("fh")[["MAPE","MASE","MdASE"]].mean().mean()
# Out:
# MAPE     0.177773
# MASE     1.108737
# MdASE    1.975542
# dtype: float64
